# %% [markdown]
# ### MNIST Classification with Simple Neural Network

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %matplotlib inline

# %% [markdown]
# #### 1. Load and prepare the MNIST dataset
#
# Reminder that the popular MNIST dataset consists of 60,000 samples of digits. Each sample is a 28x28 grayscale image with values between 0 and 255. We also have access to 10,000 supplementary samples for the final testing of the trained model.The preprocessing here consists of normalizing the samples in order to get intensities between 0 and 1.

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
print("Training data shape: ",x_train.shape)
print("Test data shape: ",x_test.shape)
print("Training labels shape: ",y_train.shape)
print("Test labels shape: ",y_test.shape)
# Out:
# Training data shape:  (60000, 28, 28)
# Test data shape:  (10000, 28, 28)
# Training labels shape:  (60000,)
# Test labels shape:  (10000,)

# %%
plt.imshow(x_test[15,:,:],cmap='gray')
plt.title('Test sample #15')
print("Digit label for test sample #15: ",y_test[15])
# Out:
# Digit label for test sample #15:  5

# %% [markdown]
# #### 2. Define the neural network model in sequential mode
#
# We are using a standard fully connected neural network here, so here are the blocks of our architecture:
# * Flatten the 28x28 image inputs to a new input tensor of 784 units
# * Create a hidden layer of 32 units with a standard ReLU activation function
# * Add an output layer of 10 units because we are doing multiclass classification (digits between 0 and 9)

# %%
model1 = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(10)])

# %%
print(model1.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                25120
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
tf.keras.utils.plot_model(model1,show_shapes=True)

# %% [markdown]
# #### 3. Define the optimizer, loss function and metric for the training procedure
#
# * Optimizer: how will the algorithm update the weights during the training procedure?
# * Loss: which function will be optimized?
# * Metric: which metric(s) will be monitored during training to make sure the algorithm is doing the right thing?

# %%
optimizer = tf.keras.optimizers.Adam() # examples: 'Adam', 'RMSprop', 'Adagrad'
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) # examples: 'BinaryCrossentropy', 'CategoricalCrossentropy'
metrics = ['accuracy']

# %% [markdown]
# #### 4. Compile and train the model
#
# For the training, we will be using a validation split of 70/30% (meaning that 70% of the training samples will be used for training and the other 30% will be used for monitoring the performance during training).

# %%
model1.compile(optimizer, loss, metrics)

# %%
model1_history = model1.fit(x=x_train, y=y_train, batch_size=32,epochs=15,validation_split=0.3)
# Out:
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/15
# 42000/42000 [==============================] - 4s 88us/sample - loss: 0.4069 - accuracy: 0.8880 - val_loss: 0.2469 - val_accuracy: 0.9274
# Epoch 2/15
# 42000/42000 [==============================] - 3s 82us/sample - loss: 0.2015 - accuracy: 0.9418 - val_loss: 0.1910 - val_accuracy: 0.9429
# Epoch 3/15
# 42000/42000 [==============================] - 4s 89us/sample - loss: 0.1556 - accuracy: 0.9549 - val_loss: 0.1695 - val_accuracy: 0.9511
# Epoch 4/15
# 42000/42000 [==============================] - 3s 81us/sample - loss: 0.1315 - accuracy: 0.9612 - val_loss: 0.1567 - val_accuracy: 0.9561
# Epoch 5/15
# 42000/42000 [==============================] - 4s 84us/sample - loss: 0.1131 - accuracy: 0.9669 - val_loss: 0.1526 - val_accuracy: 0.9571
# Epoch 6/15
# 42000/42000 [==============================] - 3s 81us/sample - loss: 0.1005 - accuracy: 0.9698 - val_loss: 0.1449 - val_accuracy: 0.9606
# Epoch 7/15
# 42000/42000 [==============================] - 4s 84us/sample - loss: 0.0908 - accuracy: 0.9733 - val_loss: 0.1405 - val_accuracy: 0.9605
# Epoch 8/15
# 42000/42000 [==============================] - 3s 81us/sample - loss: 0.0825 - accuracy: 0.9753 - val_loss: 0.1370 - val_accuracy: 0.9618
# Epoch 9/15
# 42000/42000 [==============================] - 3s 83us/sample - loss: 0.0757 - accuracy: 0.9772 - val_loss: 0.1346 - val_accuracy: 0.9626
# Epoch 10/15
# 42000/42000 [==============================] - 3s 83us/sample - loss: 0.0682 - accuracy: 0.9799 - val_loss: 0.1355 - val_accuracy: 0.9621
# Epoch 11/15
# 42000/42000 [==============================] - 4s 84us/sample - loss: 0.0637 - accuracy: 0.9814 - val_loss: 0.1394 - val_accuracy: 0.9614
# Epoch 12/15
# 42000/42000 [==============================] - 4s 84us/sample - loss: 0.0593 - accuracy: 0.9822 - val_loss: 0.1323 - val_accuracy: 0.9636
# Epoch 13/15
# 42000/42000 [==============================] - 4s 84us/sample - loss: 0.0547 - accuracy: 0.9832 - val_loss: 0.1409 - val_accuracy: 0.9630
# Epoch 14/15
# 42000/42000 [==============================] - 4s 97us/sample - loss: 0.0503 - accuracy: 0.9848 - val_loss: 0.1370 - val_accuracy: 0.9643
# Epoch 15/15
# 42000/42000 [==============================] - 4s 104us/sample - loss: 0.0468 - accuracy: 0.9856 - val_loss: 0.1525 - val_accuracy: 0.9590

# %% [markdown]
# #### 5. Plot the training loss and accuracy

# %%
# Plot training & validation accuracy values
plt.plot(model1_history.history['accuracy'])
plt.plot(model1_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(model1_history.history['loss'])
plt.plot(model1_history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# #### 6. Evaluate the performance of the trained model on test (unseen) data

# %%
model1.evaluate(x_test, y_test, verbose=2)
# Out:
# 10000/10000 - 0s - loss: 0.1297 - accuracy: 0.9631
# [0.12969627832265104, 0.9631]

# %% [markdown]
# #### 7. Make a prediction using the model

# %%
test_predicted = model1.predict_classes(x_test[10:15,:,:])
print("Classes predicted by the model: ",test_predicted)
print("Targets: ",y_test[10:15])
# Out:
# Classes predicted by the model:  [0 6 9 0 1]
# Targets:  [0 6 9 0 1]
